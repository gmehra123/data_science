# %% [markdown]
# <a href="https://colab.research.google.com/github/gmehra123/data_science_projs/blob/main/Basic_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Basic Data Structures
# 1. List collection of objects not all of the same data type
# 2. Dictionary collection of objects in key value pairs

# %%
# Basic data structures
l=[]
l=[1,2,3,'Hi',89]
# Accesing elements of a list
l[1]
# Out:
# 2

# %%
# Add an element to a list
l.append(99)
print(l)
# Out:
# [1, 2, 3, 'Hi', 89, 99, 99]

# %%
# Getting a slice from the list
l[1:4]
# Out:
# [2, 3, 'Hi']

# %%
# Dictionary
d={'element_1':[1,2,3,4,'Hi'],'element_2':45,'element_3':67}

# %%
# getting a element in a dictionary. Refer to keys
d['element_1']
# Out:
# [1, 2, 3, 4, 'Hi']

# %%
pd.DataFrame({'col1':[1,2,3,4,5],'col_2':[5,6,7,8,9]})
# Out:
#    col1  col_2
# 0     1      5
# 1     2      6
# 2     3      7
# 3     4      8
# 4     5      9

# %%
# Looping through a dictionary
for a,b in d.items():
  print(a,b)
# Out:
# element_1 23
# element_2 45
# element_3 67

# %% [markdown]
# ### Data Frames
# * Similar to dataframes in any other language
# * In python dataframes are a class with many associated methods. typically methods are applied to a dataframe with a (.) operator
# * Arranged in rows and columns
# * Every data frame will have an index by default
# * A column of a data frame is referred to as a pandas series. Again pandas series will have an index

# %%
data=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
# Check 1st 5 rows
data.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data['medv']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
# Check last 5 rows
data.tail(5)
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
# Check metadata.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
# If dataframe has too many columns you might need to add verbose=True
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ### Data frame manipulation
# 1. Filtering. Filtering is done using the .loc method.
# 2. Accessing elements of a dataframe is done using square brackets [].

# %%
# Accessing rows and columns using the loc operator. Lets filter to houses where the age is greater than 20
data.loc[data['age']>=20]
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# Filtering to houses with age >20 and the columns tax and pratio only. Typically data.loc[rows,columns]
n=data.loc[data['age']>=20,['tax','ptratio']]

# %%
n['tax']=n['tax']*1.2

# %%
# Basic checking unique values
data['chas'].unique()
# Out:
# array([0, 1])

# %%
# Using groupby
data.groupby('chas')['nox'].mean()
# Out:
# chas
# 0    0.551817
# 1    0.593426
# Name: nox, dtype: float64

# %%
#Using more than 1 measure in groupby
data.groupby('chas')['nox'].agg(['sum','mean'])
# Out:
#            sum      mean
# chas
# 0     259.9058  0.551817
# 1      20.7699  0.593426

# %%
# Grouping by multiple columns and aggregating different columns differently
data.groupby(['chas','rad']).agg({'nox':['mean','sum'],'tax':['max']})
# Out:
#                nox           tax
#               mean      sum  max
# chas rad
# 0    1    0.466147   8.8568  422
#      2    0.484917  11.6380  348
#      3    0.451781  16.2641  469
#      4    0.506747  51.6882  711
#      5    0.560189  58.2597  403
#      6    0.514846  13.3860  432
#      7    0.441000   7.4970  330
#      8    0.488684   9.2850  307
#      24   0.669605  83.0310  666
# 1    1    0.401000   0.4010  198
#      3    0.464000   0.9280  223
#      4    0.473250   3.7860  277
#      5    0.671991   7.3919  403
#      8    0.507000   2.5350  307
#      24   0.716000   5.7280  666

# %%
data.describe().transpose()
# Out:
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# b        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %% [markdown]
# ### Visualization
# * 2 basic libraries
#   * Matplotlib
#   * seaborn (more high level, better statistical graphs)

# %%
# Visualization histogram using
plt.style.use('fivethirtyeight')
fig,ax=plt.subplots(figsize=(10,6))
ax.hist(data['tax'],cumulative=True)
plt.show()

# %%
# scatterplot basic
fig,ax=plt.subplots(figsize=(10,6))
ax.scatter(x=data['nox'],y=data['lstat'])
ax.set_xlabel('NOX_value')
ax.set_ylabel('Lstat')
plt.show()

# %%
#Visualization using seaborn
import seaborn as sns

# %%
fig,ax=plt.subplots(figsize=(10,7))
plt.style.use('fivethirtyeight')
sns.scatterplot(data=data,x='lstat',y='medv',hue='nox',size='age')
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
fig,ax=plt.subplots()
ax1=sns.histplot(data=data,x='medv')

# %%
# Looking at the differenmce in distributions using boxplot
fig,ax=plt.subplots(figsize=(10,6))
sns.boxplot(data=data,y='medv',x='rad')
# Out:
# <Axes: xlabel='rad', ylabel='medv'>

# %%
# Simple random sampling
data.sample(10)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 275  0.09604  40.0   6.41     0  0.447  6.854  42.8  4.2673    4  254
# 333  0.05083   0.0   5.19     0  0.515  6.316  38.1  6.4584    5  224
# 338  0.03306   0.0   5.19     0  0.515  6.059  37.3  4.8122    5  224
# 172  0.13914   0.0   4.05     0  0.510  5.572  88.5  2.5961    5  296
# 196  0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 467  4.42228   0.0  18.10     0  0.584  6.003  94.5  2.5403   24  666
# 25   0.84054   0.0   8.14     0  0.538  5.599  85.7  4.4546    4  307
# 144  2.77974   0.0  19.58     0  0.871  4.903  97.8  1.3459    5  403
# 206  0.22969   0.0  10.59     0  0.489  6.326  52.5  4.3549    4  277
# 290  0.03502  80.0   4.95     0  0.411  6.861  27.9  5.1167    4  245
#
#      ptratio       b  lstat  medv
# 275     17.6  396.90   2.98  32.0
# 333     20.2  389.71   5.68  22.2
# 338     20.2  396.14   8.51  20.6
# 172     16.6  396.90  14.69  23.1
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
linreg=LinearRegression()

# %%
X=data.drop(columns='medv')

# %%
y=data.medv

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)

# %%
y_pred
# Out:
# array([18.70826147, 22.59503681, 25.36883362, 18.57479159, 19.13665659,
#        27.52290215, 22.98609814, 13.40088607,  1.01398522, 24.57955271,
#        23.21058871, 11.25574206, 16.94650944, 22.27077348, 20.88492586,
#        24.78590124, 23.21307714, 20.92140358, 24.95105966, 24.28012468,
#        17.12848522, 18.44322173, 24.88622491, 12.31568011, 36.12317541,
#        37.37659538, 28.56005084, 18.61805795, 33.2839363 , 21.24804852,
#        28.53429484, 15.42697743, 13.29957011, 27.55151869, 34.16648755,
#        28.88497252, 24.19486168, 30.66432993, 24.35824039, 14.70204427,
#        31.10366363, 24.25690461, 20.42933687, 20.53265598, 12.83708716,
#        16.97454424, 18.13593113, 23.29913847, 24.32993517, 30.29544557,
#        25.61390426, 28.21873937, 17.51454563, 19.65679374, 18.28128984,
#        21.24526427, 23.09302012, 20.17677263, 36.67983186, 33.1801012 ,
#        26.05078473, 38.24202174, 26.61339839, 26.9956083 , 29.86988325,
# ...

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
RMSE=np.sqrt(mse(y_test,y_pred))

# %%
RMSE
# Out:
# 4.769573815201104

# %%
X_test['predictions']=y_pred

# %%
X_test['Actuals']=y_test

# %%
X_test
# Out:
#          crim    zn  indus  chas     nox     rm    age     dis  rad  tax  \
# 61    0.17171  25.0   5.13     0  0.4530  5.966   93.4  6.8185    8  284
# 125   0.16902   0.0  25.65     0  0.5810  5.986   88.4  1.9929    2  188
# 235   0.33045   0.0   6.20     0  0.5070  6.086   61.5  3.6519    8  307
# 310   2.63548   0.0   9.90     0  0.5440  4.973   37.8  2.5194    4  304
# 137   0.35233   0.0  21.89     0  0.6240  6.454   98.4  1.8498    4  437
# ..        ...   ...    ...   ...     ...    ...    ...     ...  ...  ...
# 281   0.03705  20.0   3.33     0  0.4429  6.968   37.2  5.2447    5  216
# 455   4.75237   0.0  18.10     0  0.7130  6.525   86.5  2.4358   24  666
# 481   5.70818   0.0  18.10     0  0.5320  6.750   74.9  3.3317   24  666
# 411  14.05070   0.0  18.10     0  0.5970  6.657  100.0  1.5275   24  666
# 158   1.34284   0.0  19.58     0  0.6050  6.066  100.0  1.7573    5  403
#
#      ptratio       b  lstat  predictions  Actuals
# ...
